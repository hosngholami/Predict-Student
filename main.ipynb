# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

# %%
data = pd.read_csv("src/data.csv", sep=";")

# %% [markdown]
# ##### Marital status: وضعیت تاهل
# ##### Application mode: فرم ثبت نام
# ##### Application order ترتیب درخواست دانشجو
# ##### Course: درس های که انتخاب شده توسط دانشجو
# ##### Daytime/evening attendance: شرکت درکلاس در روز یا عصر
# ##### Previous qualification: مدرک قبلی که در مقطع قبلی کسب کرده
# ##### Nacionality: ملیت
# ##### Mother's qualification: صلاحیت مادر
# ##### Father's qualification: صلاحیت پدر
# ##### Mother's occupation: شغل مادر
# ##### Father's occupation: شغل پدر
# ##### Displaced: آواره
# ##### Educational special needs: نیاز به آموزش های خاصی دارد
# ##### Debtor: بدهکار
# ##### Tuition fees up to date: هزینه تحصیل به روز است
# ##### Gender: جنسیت
# ##### Scholarship holder: بورسیه
# ##### Age at enrollment: سن زمان ثبت نام
# ##### International: دانشجوی بین المللی
# ##### Curricular units 1st sem (credited): تعداد واحد های معتبر درسی در نیم سال اول
# ##### Curricular units 1st sem (enrolled): تعداد واحدهای درسی ثبت نام شده در نیمسال اول
# ##### Curricular units 1st sem (evaluations): تعداد واحد های ارزیابی شده درنیمسال اول
# ##### Curricular units 1st sem (approved): تعداد واحد مورد تایید توسط دانشجو در نیمسال اول
# ##### Curricular units 1st sem (grade) : نمره درس در نیم سال اول
# ##### Curricular units 1st sem (without evaluations): واحد های درسی بدون ارزشیابی
# ##### Unemployment rate: نرخ بیکاری

# %%
le = LabelEncoder()
data["Target"] = le.fit_transform(data["Target"])

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
scaler = StandardScaler()
scaler.fit(X)
scaled_data = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
result = pca.fit_transform(scaled_data)

# %%
data_scaled = pd.DataFrame(data=scaled_data, columns=X.columns)

# %%
df.max(ax)
# Out:
#     Marital status  Application mode  Application order    Course  \
# p1        0.015903          0.058235          -0.014681  0.131837
# p2        0.250065          0.358512          -0.225381 -0.038921
#
#     Daytime/evening attendance\t  Previous qualification  \
# p1                     -0.018218                0.045046
# p2                     -0.250186                0.170646
#
#     Previous qualification (grade)  Nacionality  Mother's qualification  \
# p1                       -0.000820    -0.008547                0.017530
# p2                       -0.065222    -0.006472                0.161987
#
#     Father's qualification  Mother's occupation  Father's occupation  \
# p1                0.018103            -0.003669            -0.005934
# p2                0.116110             0.075783             0.063908
#
#     Admission grade  Displaced  Educational special needs    Debtor  \
# p1         0.007855  -0.018846                  -0.013186 -0.028208
# ...

# %%
df = pd.DataFrame(data=pca.components_, columns=data_scaled.columns, index=["p1", "p2"])

# %%
pd.set_option('display.max_columns', None)

# %%
sns.heatmap(df)
# Out:
# /media/hossein/9a14f362-81ea-41b1-bc47-0fd70f8f35cd/TavaSystem/Algorimt/Predict-Student/.venv/lib/python3.11/site-packages/seaborn/utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# <Axes: >
# /media/hossein/9a14f362-81ea-41b1-bc47-0fd70f8f35cd/TavaSystem/Algorimt/Predict-Student/.venv/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /media/hossein/9a14f362-81ea-41b1-bc47-0fd70f8f35cd/TavaSystem/Algorimt/Predict-Student/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=100, test_size=0.2)

# %%
sns.scatterplot(x="p1", y="p2", data=df, hue=y)
# Out:
# <Axes: xlabel='p1', ylabel='p2'>

# %%
plt.figure(figsize=(12, 8))
plt.scatter(x_train[:,0], x_train[:,1], c=y_train)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.64116969, 0.35883031])

# %%
plt.bar(range(len(pca.explained_variance_ratio_)),pca.explained_variance_ratio_, alpha=0.5,align='center', label='individual explained variance' )
# Out:
# <BarContainer object of 2 artists>

# %%
pca.n_components_
# Out:
# 2

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state=0)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
model.score(x_train, y_train)
# Out:
# 0.6561175473297541

# %%
model.score(x_test, y_test)
# Out:
# 0.6689265536723163

# %%
y_predict = model.predict(x_test)

# %%
f = 0
t = 0
for i in range(len(y_predict)):
    if (y_predict[i] == list(y_test)[i]):
        t += 1
    else:
        f += 1
print(t, f)
print(len(y_predict))
# Out:
# 592 293
# 885

# %%
import seaborn as sns

# %%
sns.heatmap(pca.components_)
# Out:
# <Axes: >

# %%
pca.explained_variance_ratio_
# Out:
# array([0.17666395, 0.0988699 ])

# %%
plt.bar(range(2),pca.explained_variance_ratio_, alpha=0.5,align='center', label='individual explained variance' )
# Out:
# <BarContainer object of 2 artists>
